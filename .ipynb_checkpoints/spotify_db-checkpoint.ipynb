# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import sqlalchemy as db
from sqlalchemy import create_engine

# %%
path = 'clean_songs.csv'
db_path = 'sqlite:///spotify.db'

# %%
df = pd.read_csv(path)
df.drop(['Unnamed: 0', 'id'], axis=1, inplace=True)
df.index.rename('id', inplace=True)
df = pd.DataFrame(df)
df.head()
# Out:
#                              name      album                album_id  \
# id
# 0                   Downtown Life  Ooh Yeah!  4EEyCnj2fZu1eInXpLfZZW
# 1   Everything Your Heart Desires  Ooh Yeah!  4EEyCnj2fZu1eInXpLfZZW
# 2                   I'm In Pieces  Ooh Yeah!  4EEyCnj2fZu1eInXpLfZZW
# 3              Missed Opportunity  Ooh Yeah!  4EEyCnj2fZu1eInXpLfZZW
# 4               Talking All Night  Ooh Yeah!  4EEyCnj2fZu1eInXpLfZZW
#
#                         artists                  artist_ids  track_number  \
# id
# 0   ['Daryl Hall & John Oates']  ['77tT1kLj6mCWtFNqiOmP9H']             1
# 1   ['Daryl Hall & John Oates']  ['77tT1kLj6mCWtFNqiOmP9H']             2
# 2   ['Daryl Hall & John Oates']  ['77tT1kLj6mCWtFNqiOmP9H']             3
# 3   ['Daryl Hall & John Oates']  ['77tT1kLj6mCWtFNqiOmP9H']             4
# 4   ['Daryl Hall & John Oates']  ['77tT1kLj6mCWtFNqiOmP9H']             5
#
#     disc_number  explicit  danceability  energy  ...  speechiness  \
# id                                               ...
# 0             1     False         0.660   0.892  ...       0.0419
# 1             1     False         0.706   0.861  ...       0.0411
# 2             1     False         0.381   0.824  ...       0.0408
# 3             1     False         0.765   0.815  ...       0.0429
# 4             1     False         0.745   0.787  ...       0.0451
#
#     acousticness  instrumentalness  liveness  valence    tempo  duration_ms  \
# id
# 0         0.0971          0.000021    0.3500    0.767  110.089       268467
# 1         0.1570          0.000001    0.2560    0.887   99.992       300467
# 2         0.1190          0.000000    0.0826    0.805   87.064       290467
# 3         0.5230          0.000000    0.0821    0.733  106.063       287600
# 4         0.2190          0.000110    0.0910    0.902  120.925       274400
#
#     time_signature  year  release_date
# id
# 0                4  1988     7/27/1988
# 1                4  1988     7/27/1988
# 2                4  1988     7/27/1988
# 3                4  1988     7/27/1988
# 4                4  1988     7/27/1988
#
# [5 rows x 23 columns]

# %%
engine = create_engine(db_path)
conn = engine.connect()

# %%
attributes_df = df[['explicit', 'danceability', 'energy', 'loudness',
       'mode', 'speechiness', 'acousticness', 'instrumentalness', 'liveness',
       'valence', 'tempo']]

# %%
attributes_df.index.rename('attribute_id', inplace=True)
attributes_df
# Out:
#               explicit  danceability  energy  loudness  mode  speechiness  \
# attribute_id
# 0                False         0.660  0.8920    -6.545     0       0.0419
# 1                False         0.706  0.8610    -5.774     1       0.0411
# 2                False         0.381  0.8240    -6.400     1       0.0408
# 3                False         0.765  0.8150    -6.931     1       0.0429
# 4                False         0.745  0.7870    -6.328     1       0.0451
# ...                ...           ...     ...       ...   ...          ...
# 70563            False         0.630  0.7080    -9.390     1       0.0279
# 70564            False         0.673  0.2760   -15.667     1       0.0379
# 70565            False         0.665  0.3650   -18.173     0       0.0269
# 70566            False         0.630  0.3630   -18.010     1       0.0355
# 70567            False         0.558  0.0573   -19.800     0       0.0292
#
#               acousticness  instrumentalness  liveness  valence    tempo
# attribute_id
# 0                   0.0971          0.000021    0.3500   0.7670  110.089
# 1                   0.1570          0.000001    0.2560   0.8870   99.992
# 2                   0.1190          0.000000    0.0826   0.8050   87.064
# 3                   0.5230          0.000000    0.0821   0.7330  106.063
# 4                   0.2190          0.000110    0.0910   0.9020  120.925
# ...                    ...               ...       ...      ...      ...
# 70563               0.1390          0.000000    0.2090   0.8670  104.994
# 70564               0.6470          0.000002    0.0530   0.8150  180.055
# 70565               0.4430          0.000031    0.0778   0.5280  100.171
# 70566               0.4700          0.000004    0.0520   0.8990   85.673
# 70567               0.8460          0.000000    0.1130   0.0753  110.325
#
# [70568 rows x 11 columns]

# %%
# Artist Table
artist_df = pd.DataFrame(df['artists'].str.split(', ').explode('artist'))
artist_df = artist_df['artists'].drop_duplicates()
artist_df = pd.DataFrame(artist_df)
artist_df = artist_df.reset_index(drop=True)
artist_df.index.rename('artist_id', inplace=True)
artist_df
# Out:
#                                artists
# artist_id
# 0          ['Daryl Hall & John Oates']
# 1                        ['The Judds']
# 2              ['Asleep At The Wheel']
# 3            ['New Kids On The Block']
# 4                      ['Patti Smith']
# ...                                ...
# 13101       ['Death Valley Screamers']
# 13102                  ['Fatal Smile']
# 13103                         ['Roxx']
# 13104                      ['Lil Rev']
# 13105           ['Jonnie and Brookie']
#
# [13106 rows x 1 columns]

# %%
# Album Table
album = df.groupby('album')
album = album['album_id'].unique()
album = album.reset_index()
album = album.drop('album_id', axis=1)
album = pd.DataFrame(album)
album.index.rename("album_id", inplace=True)
album.head()
# Out:
#                                                       album
# album_id
# 0                                           "C" For Chicago
# 1         "Make the Yuletide Gay" Original Motion Pictur...
# 2                       "Territory" Shall Mean the Universe
# 3                                "There's Always a Way Out"
# 4         "Waking the Cobra", Vocal Meditations on the C...

# %%
# Song Table
song = df[['name', 'track_number', 'disc_number', 'duration_ms', 'time_signature', 'year', 'release_date']]
song.index.rename('song_id', inplace=True)

# %%
# add the DataFrames to the SQL database
attributes_df.to_sql(name= 'attributes', con = engine, if_exists='replace')
album.to_sql(name = 'album', con=engine, if_exists='replace')
song.to_sql(name = 'song', con=engine, if_exists='replace')
artist_df.to_sql(name = 'artist', con=engine, if_exists='replace')
